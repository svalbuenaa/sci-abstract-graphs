# %%
import networkx as nx
import itertools
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# C:\Users\svalb\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
path_data = r'C:\Users\svalb\OneDrive\Documentos\GitHub\sci-abstract-graphs\subsetPapersKeywordsDataPMID.tsv'

# %%
df=pd.read_csv(path_data, sep="\t")

# %%
df.isna('MeshHeadings')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df.isna('MeshHeadings')
#
# TypeError: DataFrame.isna() takes 1 positional argument but 2 were given

# %%
keywords_split = {}

# %%
for el in range(0, len(df)):
    keywords_split[df.iloc[el]['PMID']] = df.iloc[el]['MeshHeadings'].lower().split(',')
    
for PMID in keywords_split.keys():
    for keyword in range(0, len(keywords_split[PMID])):
        keywords_split[PMID][keyword] = keywords_split[PMID][keyword].strip()

# %%
len(keywords_split)
# Out:
# 1000

# %%
for value in keywords_split.values():
    if value == 'nan':
        print(value)

# %%
G = nx.Graph()

# %%
for keywords in keywords_split:
    for combination in itertools.combinations(keywords, 2):
        if G.has_edge(combination[0], combination[1]) or G.has_edge(combination[1], combination[0]):
            G[combination[0]][combination[1]]['weight'] += 1
        else:
            G.add_edge(combination[0], combination[1], weight = 1)

# %%
elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] > 10]
esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] <= 10]

pos = nx.spring_layout(G, seed=7)

nx.draw_networkx_nodes(G, pos)
nx.draw_networkx_edges(G, pos, edgelist=elarge, width=6)
nx.draw_networkx_edges(G, pos, edgelist=esmall, width=5, style="dashed")

nx.draw_networkx_labels(G, pos, font_size=10, font_color="r", font_family="sans-serif")
# edge weight labels
edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels, font_size=10, font_color="r")

ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
threshold_weight = 150

nodes_to_keep = set()
for u, v, data in G.edges(data=True):
    if data['weight'] > threshold_weight:
        nodes_to_keep.update([u, v])

# %%
nodes_to_keep
# Out:
# {'80 and over',
#  'adult',
#  'aged',
#  'animals',
#  'carcinoma',
#  'cultured',
#  'female',
#  'humans',
#  'leukemia',
#  'male',
#  'mice',
#  'middle aged',
#  'tumor cells'}

# %%
H = G.subgraph(nodes_to_keep)

# %%
H = nx.Graph(H)
self_loops = list(nx.selfloop_edges(H))
H.remove_edges_from(self_loops)

# %%
elarge_3 = [(u, v) for (u, v, d) in H.edges(data=True) if d["weight"] > 200]
esmall_3 = [(u, v) for (u, v, d) in H.edges(data=True) if d["weight"] <= 200 and d["weight"] >100]
edge_labels = nx.get_edge_attributes(H, "weight")
edge_labels_2 = edge_labels.copy()
for key in edge_labels.keys():
    if edge_labels[key] <= 100:
        edge_labels_2.pop(key)

# %%
plt.figure(figsize=(16, 8))
pos = nx.spring_layout(H, seed=7)

nx.draw_networkx_nodes(H, pos)
nx.draw_networkx_edges(H, pos, edgelist=elarge_3, width=2)
nx.draw_networkx_edges(H, pos, edgelist=esmall_3, width=1, style="dashed")

nx.draw_networkx_labels(H, pos, font_size=16, font_color="r", font_family="sans-serif")
# edge weight labels

nx.draw_networkx_edge_labels(H, pos, edge_labels_2, font_size=12, font_color="r")

ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
plt.tight_layout()
plt.show()
